# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Data Collection and Processing

# %%
# loading the csv data to a Pandas DataFrame
Breast_data = pd.read_csv('F:/New chapter/PG/DSA/Behredin_Disease_Pr/Breast_cancer_data.csv')

# %%
# print first 5 rows of the dataset
Breast_data.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    diagnosis
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# print last 5 rows of the dataset
Breast_data.tail()
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      diagnosis
# 564          0
# 565          0
# 566          0
# 567          0
# 568          1

# %%
# number of rows and columns in the dataset
Breast_data.shape
# Out:
# (569, 6)

# %%
# getting some info about the data
Breast_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mean_radius      569 non-null    float64
#  1   mean_texture     569 non-null    float64
#  2   mean_perimeter   569 non-null    float64
#  3   mean_area        569 non-null    float64
#  4   mean_smoothness  569 non-null    float64
#  5   diagnosis        569 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 26.8 KB

# %%
# checking for missing values
Breast_data.isnull().sum()
# Out:
# mean_radius        0
# mean_texture       0
# mean_perimeter     0
# mean_area          0
# mean_smoothness    0
# diagnosis          0
# dtype: int64

# %%
# statistical measures about the data
Breast_data.describe()
# Out:
#        mean_radius  mean_texture  mean_perimeter    mean_area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean_smoothness   diagnosis
# count       569.000000  569.000000
# mean          0.096360    0.627417
# std           0.014064    0.483918
# min           0.052630    0.000000
# 25%           0.086370    0.000000
# 50%           0.095870    1.000000
# 75%           0.105300    1.000000
# max           0.163400    1.000000

# %%
# checking the distribution of Target Variable
Breast_data['diagnosis'].value_counts()
# Out:
# 1    357
# 0    212
# Name: diagnosis, dtype: int64

# %%
sns.countplot(Breast_data['diagnosis'])
# Out:
# c:\Users\mohamed\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %% [markdown]
# Show Fasting Blood Sugar Distribution According to the target variable

# %%
sns.countplot(x="mean_area",hue="diagnosis",data=Breast_data)
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# Check Resting Bood Pressure Distribution

# %%
Breast_data['mean_radius'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Splitting the Features and Target

# %%
X = Breast_data.drop(columns='diagnosis', axis=1)
Y = Breast_data['diagnosis']

# %%
print(X)
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# [569 rows x 5 columns]

# %%
print(Y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: diagnosis, Length: 569, dtype: int64

# %% [markdown]
# Splitting the Data into Training data & Test Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (569, 5) (455, 5) (114, 5)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the LogisticRegression model with Training data
model.fit(X_train, Y_train)
# Out:
# c:\Users\mohamed\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9120879120879121

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.9035087719298246

# %% [markdown]
# Building a Predictive System

# %%
input_data = (15.22	,30.62	,103.4,	716.9,	0.1048)

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have Breast Cancer Disease')
else:
  print('The Person has Breast Cancer Disease')
# Out:
# [0]
# The Person does not have Breast Cancer Disease
# c:\Users\mohamed\anaconda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Saving the trained model

# %%
import pickle

# %%
filename = 'F:/New chapter/PG/DSA/Behredin_Disease_Pr/breast_disease_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
# loading the saved model
loaded_model = pickle.load(open('F:/New chapter/PG/DSA/Behredin_Disease_Pr/breast_disease_model.sav', 'rb'))

# %%
for column in X.columns:
  print(column)
# Out:
# mean_radius
# mean_texture
# mean_perimeter
# mean_area
# mean_smoothness
